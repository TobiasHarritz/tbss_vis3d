# %%
pip install -e .
# Out:
# Obtaining file:///Users/tobiasharritz/code/tbss_vis3d
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for tbss_vis3d (pyproject.toml) ... done
#   Created wheel for tbss_vis3d: filename=tbss_vis3d-0.1.0-0.editable-py3-none-any.whl size=4018 sha256=3ea8d97aa5e08cb5cdf00da9d10296285be5e858d25a417883543096636c094e
#   Stored in directory: /private/var/folders/cc/kcw51_v152n0d0vggysd__sh0000gq/T/pip-ephem-wheel-cache-lar_5p31/wheels/59/0d/ea/10be7fc5f29062abaa1335dcc00ed0105f44f5306633aefec3
# Successfully built tbss_vis3d
# ...
#   Attempting uninstall: tbss_vis3d
#     Found existing installation: tbss_vis3d 0.1.0
#     Uninstalling tbss_vis3d-0.1.0:
#       Successfully uninstalled tbss_vis3d-0.1.0
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from tbss_vis3d import render

# %%
example_in = "/Users/tobiasharritz/data/tbss_example/ExBox7/tbss_clustere_corrp_tstat1.nii.gz"

r = render(example_in, style="voxels", cmap="autumn")


iso = r.iso
top = r.top(zoom='1.5')
side = r.side
# Out:
# /Users/tobiasharritz/code/tbss_vis3d/tbss_vis3d/render.py:71: FutureWarning: 'force_resample' will be set to 'True' by default in Nilearn 0.13.0.
# Use 'force_resample=True' to suppress this warning.
#   stat_img = image.resample_to_img(stat_img, template_img, interpolation=interpolation)
# /Users/tobiasharritz/miniconda3/envs/py3.13/lib/python3.13/site-packages/nilearn/image/resampling.py:805: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   return resample_img(

# %%
from matplotlib import pyplot as plt

plt.imshow(iso(zoom='1.7'))
plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
